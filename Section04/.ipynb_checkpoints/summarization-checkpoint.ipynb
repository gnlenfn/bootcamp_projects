# %% [markdown]
# # Text summarization
# https://www.kaggle.com/snap/amazon-fine-food-reviews
# kaggle에서 찾은 아마존 음식리뷰 데이터

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
import os
np.random.seed(seed=777)

# %% [markdown]
# # 1. 데이터 불러오기

# %%
data = pd.read_csv("reviews/Reviews.csv", encoding='utf-8')
data.shape
# Out:
# (568454, 10)

# %%
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# 실제 텍스트인 'Text'와 label이 될 요약본인 'Summary'만 사용할 것이다

# %%
data = data[['Text', 'Summary']]
data.head()
# Out:
#                                                 Text                Summary
# 0  I have bought several of the Vitality canned d...  Good Quality Dog Food
# 1  Product arrived labeled as Jumbo Salted Peanut...      Not as Advertised
# 2  This is a confection that has been around a fe...  "Delight" says it all
# 3  If you are looking for the secret ingredient i...         Cough Medicine
# 4  Great taffy at a great price.  There was a wid...            Great taffy

# %% [markdown]
# # 2. 데이터 전처리
#
# ### 1) 중복 및 Null 제거

# %%
print(data['Text'].nunique())
print(data['Summary'].nunique())
# Out:
# 393579
# 295742

# %% [markdown]
# 원문이 비해 요약의 중복이 많은 것은 다른 내용도 같은 요약일 수 있기 때문?
# 전체 리뷰가 약 56만개였는데 중복이 아주 많다.

# %%
data.drop_duplicates(subset=['Text'], inplace=True)
data.shape
# Out:
# (393579, 2)

# %%
# null 확인
data.isnull().sum()
# Out:
# Text       0
# Summary    3
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)
data.shape
# Out:
# (393576, 2)

# %% [markdown]
# ### 2) 축약어 원복

# %%
# expand contractions
# from wikipedia table
contractions = { 
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he has",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I had",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she has",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}

# %%
# NLTK stopwords
stop_words = set(stopwords.words('english'))
len(stop_words)
# Out:
# 179

# %%
# preprocessing!
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower()                     # lower case
    sentence = BeautifulSoup(sentence, "lxml").text # remove HTML tags
    sentence = re.sub(r'\([^)]*\)', '', sentence)   # remove parentheses
    sentence = re.sub('"', "", sentence)            # remove ""
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # expand contractions
   # sentence = re.sub(r"s\b", "", sentence)         # remove possesive
    sentence = re.sub(r'[^a-zA-Z]', " ", sentence)     # remove all except english
    sentence = re.sub('[m]{2,}', 'mm', sentence)    # Ex) hmmmmmmmm -> hmm 한국어로 치면 ㅋㅋㅋ 너무많은것 줄이는 것
    
    if remove_stopwords:
        tokens = " ".join(word for word in sentence.split() if not word in stop_words if len(word) > 1)
    else:
        tokens = " ".join(word for word in sentence.split() if len(word) > 1)
        
    return tokens

# %%
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_summary = 'Great way to start (or finish) the day!!!'
print(preprocess_sentence(temp_text))
print(preprocess_sentence(temp_summary, 0))
# Out:
# everything bought wa great infact ordered twice third ordered wasfor mother father
# great way to start the day

# %%
data['Text'] = data['Text'].apply(preprocess_sentence)
data['Summary'] = data['Summary'].apply(preprocess_sentence)
# Out:
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:424: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/b007i7yygy/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:336: MarkupResemblesLocatorWarning: "." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:424: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/b000v9lq30/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:424: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/b001eq58fq/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning
# /usr/local/lib/python3.6/dist-packages/bs4/__init__.py:424: MarkupResemblesLocatorWarning: "http://www.amazon.com/gp/product/b000eyobru/ref=cm_cr_rev_prod_title" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   MarkupResemblesLocatorWarning

# %%
data.replace('', np.nan, inplace=True)
print(data.isnull().sum())
# Out:
# Text          3
# Summary    1225
# dtype: int64

# %%
data.dropna(axis = 0, inplace = True)
len(data)
# Out:
# 392350

# %%
# 길이 분포 출력
text_len = [len(s.split()) for s in data['Text']]
summary_len = [len(s.split()) for s in data['Summary']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(summary_len)))
print('요약의 최대 길이 : {}'.format(np.max(summary_len)))
print('요약의 평균 길이 : {}'.format(np.mean(summary_len)))

plt.subplot(1,2,1)
plt.boxplot(summary_len)
plt.title('Summary')
plt.subplot(1,2,2)
plt.boxplot(text_len)
plt.title('Text')
plt.tight_layout()
plt.show()

plt.title('Summary')
plt.hist(summary_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('Text')
plt.hist(text_len, bins=40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 1
# 텍스트의 최대 길이 : 1992
# 텍스트의 평균 길이 : 40.09066139926087
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 18
# 요약의 평균 길이 : 2.905089843252198

# %%
text_max_len = 80
summary_max_len = 6

# %%
def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s.split()) <= max_len):
            cnt = cnt + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))

# %%
below_threshold_len(text_max_len, data['Text'])
# Out:
# 전체 샘플 중 길이가 80 이하인 샘플의 비율: 0.9034841340639735

# %%
below_threshold_len(summary_max_len, data['Summary'])
# Out:
# 전체 샘플 중 길이가 6 이하인 샘플의 비율: 0.9702000764623423

# %%
data = data[data['Text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['Summary'].apply(lambda x: len(x.split()) <= summary_max_len)]
print('전체 샘플수 :',(len(data)))
# Out:
# 전체 샘플수 : 346261

# %% [markdown]
# ### 3) sos, eos token 추가

# %%
data['decoder_input'] = data['Summary'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['Summary'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
#                                                 Text                Summary  \
# 0  bought several vitality canned dog food produc...  good quality dog food
# 1  product arrived labeled jumbo salted peanut pe...             advertised
# 2  thi confection ha around centurie light pillow...            delight say
# 3  looking secret ingredient robitussin believe f...         cough medicine
# 4  great taffy great price wa wide assortment yum...            great taffy
#
#                     decoder_input                  decoder_target
# 0  sostoken good quality dog food  good quality dog food eostoken
# 1             sostoken advertised             advertised eostoken
# 2            sostoken delight say            delight say eostoken
# 3         sostoken cough medicine         cough medicine eostoken
# 4            sostoken great taffy            great taffy eostoken

# %%
encoder_input = np.array(data['Text'])
decoder_input = np.array(data['decoder_input'])
decoder_target = np.array(data['decoder_target'])

# %% [markdown]
# # 2. Train/Test Split

# %%
# shuffle data
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)

encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]

# %%
num_vals = int(len(encoder_input)*0.2) # 80:20 split
num_vals
# Out:
# 69252

# %%
encoder_input_train = encoder_input[:-num_vals]
decoder_input_train = decoder_input[:-num_vals]
decoder_target_train = decoder_target[:-num_vals]

encoder_input_test = encoder_input[-num_vals:]
decoder_input_test = decoder_input[-num_vals:]
decoder_target_test = decoder_target[-num_vals:]

# %%
print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :',len(decoder_input_train))
print('테스트 데이터의 개수 :',len(encoder_input_test))
print('테스트 레이블의 개수 :',len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 277009
# 훈련 레이블의 개수 : 277009
# 테스트 데이터의 개수 : 69252
# 테스트 레이블의 개수 : 69252

# %% [markdown]
# # 3. encoding

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(encoder_input_train)

# %%
threshold = 7
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 75435
# 등장 빈도가 6번 이하인 희귀 단어의 수: 57448
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 17987
# 단어 집합에서 희귀 단어의 비율: 76.15563067541592
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.1443860089885727

# %% [markdown]
# unique tokens 중 5번 이하로 나오는 token들은 약 56000개로 토큰의 74%에 해당하지만, 전체 token에서 1%밖에 차지하지 않는다. --> 삭제할 것
#
# ### 1) encoder_input encoding

# %%
src_vocab = 18000
src_tokenizer = Tokenizer(num_words = src_vocab) 
src_tokenizer.fit_on_texts(encoder_input_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# %%
encoder_input_train[:3]
# Out:
# [[1,
#   119,
#   1395,
#   359,
#   1923,
#   125,
#   394,
#   2470,
#   582,
#   63,
#   102,
#   2471,
#   16815,
#   1598,
#   394,
#   272,
#   1,
#   10,
#   4,
#   181,
#   1598,
#   3887,
#   394,
#   7,
#   446,
#   102,
#   5200,
#   1395,
#   424,
#   12,
#   175,
#   617,
#   39,
#   307,
#   2001,
#   5316,
#   2027,
#   3030,
#   2385,
#   27,
#   60,
#   146,
#   3,
#   916,
#   2234,
#   60,
#   533,
#   1119,
#   986,
#   394,
#   178,
#   1107,
#   2470,
#   63,
#   60,
#   257,
#   4,
#   373,
#   2385,
#   1,
#   38,
#   1301,
#   97,
#   1009,
#   471,
#   885,
#   2336,
#   1188],
#  [6, 7, 34, 170, 22, 412, 28, 137, 127, 19, 102, 19, 547],
#  [65,
#   73,
#   202,
#   96,
#   1,
#   50,
#   24,
#   4204,
#   3585,
#   241,
#   78,
#   21,
#   2057,
#   55,
#   111,
#   7,
#   4917,
#   370,
#   15,
#   124,
#   295,
#   562,
#   202,
#   96,
#   19,
#   1377,
#   11715,
#   1837,
#   1377,
#   85,
#   38,
#   34,
#   237,
#   478,
#   458,
#   226,
#   14,
#   1060,
#   193,
#   7016,
#   7325,
#   3508,
#   264,
#   20,
#   39,
#   143,
#   197,
#   28,
#   82,
#   228,
#   16,
#   129,
#   219,
#   562,
#   202,
#   96,
#   17,
#   4741,
#   76,
#   609,
#   109,
#   7,
#   535,
#   7]]

# %% [markdown]
# ### 2) decoder_input encoding

# %%
threshold = 6
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 75435
# 등장 빈도가 5번 이하인 희귀 단어의 수: 56050
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 19385
# 단어 집합에서 희귀 단어의 비율: 74.30237953204745
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.0454954390438314

# %%
tar_vocab = 19000
tar_tokenizer = Tokenizer(num_words = tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# %%
decoder_input_train[:5]
# Out:
# [[1, 75, 309, 261, 222],
#  [1, 6],
#  [1, 1221, 37],
#  [1, 107, 37, 10, 147, 255],
#  [1, 8, 3, 10]]

# %% [markdown]
# ### 3) remove empty samples

# %%
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 610
# 삭제할 테스트 데이터의 개수 : 512

# %% [markdown]
# ### 4) padding

# %%
encoder_input_train = pad_sequences(encoder_input_train, maxlen = text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen = text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen = summary_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen = summary_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen = summary_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen = summary_max_len, padding='post')

# %% [markdown]
# # 4. Model Training

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
decoder_lstm = LSTM(hidden_size, return_sequences = True, return_state = True, dropout = 0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state = [state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation = 'softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 80, 128)      2304000     input_8[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   [(None, 80, 256), (N 394240      embedding_4[0][0]
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_9 (LSTM)                   [(None, 80, 256), (N 525312      lstm_8[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, None, 128)    2432000     input_9[0][0]
# __________________________________________________________________________________________________
# lstm_10 (LSTM)                  [(None, 80, 256), (N 525312      lstm_9[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  [(None, None, 256),  394240      embedding_5[0][0]
#                                                                  lstm_10[0][1]
#                                                                  lstm_10[0][2]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, None, 19000)  4883000     lstm_11[0][0]
# ==================================================================================================
# Total params: 11,458,104
# Trainable params: 11,458,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Download Bahdanau Attention
urllib.request.urlretrieve("https://raw.githubusercontent.com/thushv89/attention_keras/master/src/layers/attention.py", filename="attention.py")
from attention import AttentionLayer

# %%
# 어텐션 층(어텐션 함수)
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis = -1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 80)]         0
# __________________________________________________________________________________________________
# embedding_4 (Embedding)         (None, 80, 128)      2304000     input_8[0][0]
# __________________________________________________________________________________________________
# lstm_8 (LSTM)                   [(None, 80, 256), (N 394240      embedding_4[0][0]
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# lstm_9 (LSTM)                   [(None, 80, 256), (N 525312      lstm_8[0][0]
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, None, 128)    2432000     input_9[0][0]
# __________________________________________________________________________________________________
# lstm_10 (LSTM)                  [(None, 80, 256), (N 525312      lstm_9[0][0]
# __________________________________________________________________________________________________
# lstm_11 (LSTM)                  [(None, None, 256),  394240      embedding_5[0][0]
#                                                                  lstm_10[0][1]
#                                                                  lstm_10[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 256),  131328      lstm_10[0][0]
#                                                                  lstm_11[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 512)    0           lstm_11[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, None, 19000)  9747000     concat_layer[0][0]
# ==================================================================================================
# Total params: 16,453,432
# Trainable params: 16,453,432
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
import tensorflow as tf

# %%
checkpoint_path = './checkpoints/training_checkpoints_{epoch:02d}.hdf5'
checkpoint_dir = os.path.dirname(checkpoint_path)# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                    save_weights_only=True,
                                    save_best_only=True,
                                    verbose=1)
# Train the model with the new callback

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience = 10)
history = model.fit(x = [encoder_input_train, decoder_input_train], y = decoder_target_train, \
          validation_data = ([encoder_input_test, decoder_input_test], decoder_target_test),
          batch_size = 256, callbacks=[es, cp_callback], epochs = 50)
# Out:
# Epoch 1/50
# 1083/1083 [==============================] - 142s 131ms/step - loss: 2.3558 - accuracy: 0.6285 - val_loss: 2.3810 - val_accuracy: 0.6267
#
# Epoch 00001: val_loss improved from inf to 2.38098, saving model to ./checkpoints/training_checkpoints_01.hdf5
# Epoch 2/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.3339 - accuracy: 0.6299 - val_loss: 2.3637 - val_accuracy: 0.6277
#
# Epoch 00002: val_loss improved from 2.38098 to 2.36374, saving model to ./checkpoints/training_checkpoints_02.hdf5
# Epoch 3/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.3167 - accuracy: 0.6313 - val_loss: 2.3582 - val_accuracy: 0.6282
#
# Epoch 00003: val_loss improved from 2.36374 to 2.35821, saving model to ./checkpoints/training_checkpoints_03.hdf5
# Epoch 4/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.3036 - accuracy: 0.6327 - val_loss: 2.3605 - val_accuracy: 0.6270
#
# Epoch 00004: val_loss did not improve from 2.35821
# Epoch 5/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.2920 - accuracy: 0.6337 - val_loss: 2.3563 - val_accuracy: 0.6269
#
# Epoch 00005: val_loss improved from 2.35821 to 2.35632, saving model to ./checkpoints/training_checkpoints_05.hdf5
# Epoch 6/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.2774 - accuracy: 0.6347 - val_loss: 2.3419 - val_accuracy: 0.6288
#
# Epoch 00006: val_loss improved from 2.35632 to 2.34194, saving model to ./checkpoints/training_checkpoints_06.hdf5
# Epoch 7/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.2668 - accuracy: 0.6356 - val_loss: 2.3377 - val_accuracy: 0.6305
#
# Epoch 00007: val_loss improved from 2.34194 to 2.33774, saving model to ./checkpoints/training_checkpoints_07.hdf5
# Epoch 8/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.2543 - accuracy: 0.6363 - val_loss: 2.3467 - val_accuracy: 0.6301
#
# Epoch 00008: val_loss did not improve from 2.33774
# Epoch 9/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.2433 - accuracy: 0.6371 - val_loss: 2.3394 - val_accuracy: 0.6305
#
# Epoch 00009: val_loss did not improve from 2.33774
# Epoch 10/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.2322 - accuracy: 0.6378 - val_loss: 2.3683 - val_accuracy: 0.6302
#
# Epoch 00010: val_loss did not improve from 2.33774
# Epoch 11/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.2213 - accuracy: 0.6387 - val_loss: 2.3336 - val_accuracy: 0.6285
#
# Epoch 00011: val_loss improved from 2.33774 to 2.33357, saving model to ./checkpoints/training_checkpoints_11.hdf5
# Epoch 12/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.2115 - accuracy: 0.6392 - val_loss: 2.3429 - val_accuracy: 0.6262
#
# Epoch 00012: val_loss did not improve from 2.33357
# Epoch 13/50
# 1083/1083 [==============================] - 144s 133ms/step - loss: 2.2026 - accuracy: 0.6397 - val_loss: 2.3407 - val_accuracy: 0.6294
#
# Epoch 00013: val_loss did not improve from 2.33357
# Epoch 14/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.1951 - accuracy: 0.6403 - val_loss: 2.3304 - val_accuracy: 0.6291
#
# Epoch 00014: val_loss improved from 2.33357 to 2.33041, saving model to ./checkpoints/training_checkpoints_14.hdf5
# Epoch 15/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.1857 - accuracy: 0.6405 - val_loss: 2.3555 - val_accuracy: 0.6312
#
# Epoch 00015: val_loss did not improve from 2.33041
# Epoch 16/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.1765 - accuracy: 0.6408 - val_loss: 2.3435 - val_accuracy: 0.6301
#
# Epoch 00016: val_loss did not improve from 2.33041
# Epoch 17/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.1637 - accuracy: 0.6417 - val_loss: 2.3455 - val_accuracy: 0.6276
#
# Epoch 00017: val_loss did not improve from 2.33041
# Epoch 18/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.1517 - accuracy: 0.6425 - val_loss: 2.3552 - val_accuracy: 0.6309
#
# Epoch 00018: val_loss did not improve from 2.33041
# Epoch 19/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.1406 - accuracy: 0.6430 - val_loss: 2.3440 - val_accuracy: 0.6296
#
# Epoch 00019: val_loss did not improve from 2.33041
# Epoch 20/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.1310 - accuracy: 0.6438 - val_loss: 2.3574 - val_accuracy: 0.6263
#
# Epoch 00020: val_loss did not improve from 2.33041
# Epoch 21/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.1217 - accuracy: 0.6440 - val_loss: 2.3654 - val_accuracy: 0.6251
#
# Epoch 00021: val_loss did not improve from 2.33041
# Epoch 22/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.1111 - accuracy: 0.6443 - val_loss: 2.3614 - val_accuracy: 0.6259
#
# Epoch 00022: val_loss did not improve from 2.33041
# Epoch 23/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.0970 - accuracy: 0.6454 - val_loss: 2.3688 - val_accuracy: 0.6247
#
# Epoch 00023: val_loss did not improve from 2.33041
# Epoch 24/50
# 1083/1083 [==============================] - 143s 132ms/step - loss: 2.0829 - accuracy: 0.6456 - val_loss: 2.3516 - val_accuracy: 0.6287
#
# Epoch 00024: val_loss did not improve from 2.33041
# Epoch 00024: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='test')
plt.legend()
plt.show()

# %%
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

# %%
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# %%
# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)
# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if(sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (summary_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if(i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

# %%
for i in range(500, 1000):
    print("원문 : ",seq2text(encoder_input_test[i]))
    print("실제 요약문 :",seq2summary(decoder_input_test[i]))
    print("예측 요약문 :",decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 :  dog love treat lb husky mix clean hi teeth pretty well give one day sometime give day notice plaque hi teeth like hide around house eat get hungry
# 실제 요약문 : great treat good cleaning
# 예측 요약문 :  dog love
#
#
# 원문 :  considering want pay shipping charge found locally decided give try made manhattan frozen drink party last night nobody particularly raved syrup thick rich quite good worth exorbitant price probably buy
# 실제 요약문 : really good expensive
# 예측 요약문 :  good stuff
#
#
# 원문 :  never energy drink guy kick ha definitely converted drink much taste energy watch redbull
# 실제 요약문 : keep kicking
# 예측 요약문 :  energy drink
#
#
# 원문 :  thi item sweat soymilk also ha strong artificial flavor look person made product doe like soymilk added lot stuff cover original taste much sugar make product unhealthy
# 실제 요약문 : better product
# 예측 요약문 :  good
#
#
# 원문 :  sent grandmother wa rehab center loved lasted longer floral arrangement received proflower wonderful used several time recipient alway love get
# 실제 요약문 : grandmother loved
# 예측 요약문 :  beautiful
#
#
# 원문 :  purchased boyfriend say good bean nice sheen bit larger like sealable use really make great gift highly recommend coffee snob friend disappointed
# 실제 요약문 : great way start morning
# 예측 요약문 :  great coffee
#
#
# 원문 :  finally strong cup coffee found lot coffee ground bottom cup also foil wa allowing coffee ground spill throughout box
# 실제 요약문 : strong coffee
# 예측 요약문 :  coffee
#
#
# 원문 :  wife really like fruit strip granddaughter like also wife carrie quick pick needed
# 실제 요약문 :
# 예측 요약문 :  fruit cider
#
#
# 원문 :  thi item arrived pretty quick ordered monday arrived thursday packaging wa secure arrived great shape using thi smoothie defintely continue use hempseed major ingredient felt energy boost mood wa vastly improved
# 실제 요약문 : great
# 예측 요약문 :  great product
#
#
# 원문 :  passed colorado ski trip giving free taste thi costco best hot sauce known man bought several bottle put everything pizza slice salad chicken breast chicken nugget meatball officially addicted wish amazon would sell bigger bottle
# 실제 요약문 : great everything
# 예측 요약문 :  best hot sauce ever
#
#
# 원문 :  ordered thi based glowing review wa disappointed blandest chocolate cake ever tasted made three boxe alway end spitting first bite final product also call ton egg oil good however love natural think natural mean bland though opinion thi need much stronger richer chocolate flavor last batch tried adding chocolate chip additional flavor trick sure last three boxe
# 실제 요약문 : bland
# 예측 요약문 :  disappointing
#
#
# 원문 :  pudding american standard name somewhat obscene american standard found thi treat sweet ha long long time since seen bread tasted much better heating microwave pouring cream half half top give thi gift christma birthday almost everyone love give anyone work hr department learned hard way
# 실제 요약문 : fun treat
# 예측 요약문 :  love thi stuff
#
#
# 원문 :  wish read review making thi purchase basically box sticky outside pink ish thing look like entrance trap picture inside trap flie stuck outside basically fly paper horribly horribly horribly overpriced favor get fly paper fly strip yuck factor much cheaper
# 실제 요약문 : big rip
# 예측 요약문 :  waste money
#
#
# 원문 :  let get real thi equal world clas hot chocolate made valrhona scharffen berger chocolate whole milk little cream added real sugar calorie ever taste good let say calorie calorie excellent search long time better low calorie snack also help chocolate craving find snack please let know commented sweet found let cool warm hot artificial sweetener taste strong taste like chocolate remember think worth star
# 실제 요약문 : world clas hot cocoa exactly
# 예측 요약문 :  chocolate
#
#
# 원문 :  wa excited purchase thi tea found good brewed small setting big weak quality one raspberry one lemon figure get rid
# 실제 요약문 : tastles weak sweet buy
# 예측 요약문 :  good tea
#
#
# 원문 :  thi really good reasonably priced baking mix chocolate chip cookie made recipe box die yum mis gluten use thi everything bake last box include butter chocolate chip cookie recipe without butter bread like put stick softened butter margarine recipe enjoy
# 실제 요약문 : good
# 예측 요약문 :  great baking mix
#
#
# 원문 :  bottle arrived time sushi dinner game night planned friend three soy sauce choose sampling using everyone enjoyed light smoothnes subtle sweetnes splashing right every piece rather dunking dipping friend wanted know found going back order right ordering extra bottle going make great little gift affordable unique instead traditional bottle wine common boring
# 실제 요약문 : get vote
# 예측 요약문 :  deliciou
#
#
# 원문 :  really enjoy thi product natural healthy sport drink wonderful mild flavor
# 실제 요약문 : wonderful mild coconut flavor
# 예측 요약문 :  great product
#
#
# 원문 :  st loui ha amazing wing sauce moving back kansa city still thi sauce shipped cannot live without
# 실제 요약문 : best wing sauce
# 예측 요약문 :  best sauce ever
#
#
# 원문 :  youve never tried pepsi dont youll get addicted good get addicted soft drink one addiction life havent able break like rc dont sell area soda grade pepsi nothing
# 실제 요약문 : pepsi good
# 예측 요약문 :  love thi stuff
#
#
# 원문 :  disappointed taste wa expected description vegan book read try bar cherry pie wa sweet pleasant
# 실제 요약문 : care cherry pie version
# 예측 요약문 :  expected
#
#
# 원문 :  delight find great greek coffee family overwhelmed make home good coffee good buy
# 실제 요약문 : true greek
# 예측 요약문 :  coffee
#
#
# 원문 :  used thi last night great tasting spaghetti packaging wa good came reasonable time good job
# 실제 요약문 : great taste
# 예측 요약문 :  spaghetti
#
#
# 원문 :  cutter spray work fairly well week advertised live outside houston nothing really work totally thi keep getting really bad apply every week would buy amazon asking local lowe
# 실제 요약문 : lowe
# 예측 요약문 :  work
#
#
# 원문 :  first getting shipment good time important thi came good time second good shape damaged packaging lastly product taste wonderful love thi product everything egg soup would definitely buy
# 실제 요약문 : good pepper
# 예측 요약문 :  good product
#
#
# 원문 :  really like licorice mint combo dissolve fast like take several one another seemed like good value
# 실제 요약문 : great flavor
# 예측 요약문 :  good
#
#
# 원문 :  several previou order mccann steel cut oatmeal arrived dented happy tell packaging ha improved arrived perfect condition great product great packaging
# 실제 요약문 : perfect condition
# 예측 요약문 :  great product
#
#
# 원문 :  oat favorite kind whole grain oat based cereal cheerio bit expensive thi thi beat texture flavor eating dry straight box quaker product line ha thing like know spot brand name find new way enjoy oat rarely go sale supermarket lowest seen wa wa ny got buried snow power week missed stocking
# 실제 요약문 : one favorite cereal
# 예측 요약문 :  best oat bran
#
#
# 원문 :  thi coffee wa deliciou smooth ha great flavor package wa super hard open know way wa mine regardles would highly recommend thi coffee
# 실제 요약문 : deliciou
# 예측 요약문 :  deliciou
#
#
# 원문 :  thi fun hilariou stocking stuffer person receiving thi need really good sense humor instruction included made thi easy fill prepare christma morning
# 실제 요약문 : pooping reindeer stocking stuffer
# 예측 요약문 :  fun fun
#
#
# 원문 :  little cup perfect compliment cup varietie use coffee loose tea wa disappointed much easier use reuseable cup sold keurig
# 실제 요약문 : great substitute
# 예측 요약문 :  love
#
#
# 원문 :  enjoyed soon opened box also purchased hot short beef shot incredible leave wonderful hot warmth mouth much better oberto went school guy friend family good thi better mind excellent stick bland icky great
# 실제 요약문 : oh goodnes spicy perfect meat greasy
# 예측 요약문 :  best hot sauce ever
#
#
# 원문 :  remember ritz bit ate kid well thi taste exactly like different shape ritz make new innovative product took lousy recipe changed way look
# 실제 요약문 : taste like larger version ritz bit
# 예측 요약문 :  remember
#
#
# 원문 :  usually like licorice licorice flavored newman pomegranate twist step vine twizzler taste department red vine alway tasted well red pomegranate twist pleasant distinct taste picked blindfolded dark movie theater serving size piece yielding calorie yet fat low sodium best yet fiber twist price actually quite bit higher competition gues get pay think may sneak next visit
# 실제 요약문 : better competition
# 예측 요약문 :  tasty
#
#
# 원문 :  family ha hooked senseo coffee year dark roast best nice rich full flavored cup coffee
# 실제 요약문 : senseo coffee great
# 예측 요약문 :  senseo coffee pod
#
#
# 원문 :  thi best olive oil ever tasted tasted lot olive oil life forget making vinaigrette salad use straight smooth buttery tasting drizzle thi anything disappointed cook bake
# 실제 요약문 : like butter
# 예측 요약문 :  best olive oil
#
#
# 원문 :  fan thi tea remarkable one taste never buy supermarket perfume everything teapot family room scent gentler kinder time
# 실제 요약문 : best tea ever
# 예측 요약문 :  yorkshire gold tea
#
#
# 원문 :  love swedish fish wa horrified received bag deceased fish bag wa torn open box hard rock melted bloody red mes made house extreme one bag never eat one switched blue gummy shark
# 실제 요약문 : swedish fish arrived dead
# 예측 요약문 :  stale
#
#
# 원문 :  ferrara pan candy company atomic know around since beginning time consistent quality buy bag week people work people live animal see long suck changing side mouth look like people going around fat jaw red coating wear seem get hotter hear tell tale sound people crunching get come back
# 실제 요약문 : try little
# 예측 요약문 :  love thi stuff
#
#
# 원문 :  thi product help balance dog cat digestive tract wa recommended holistic veterinary practitioner great product order
# 실제 요약문 : great stuff
# 예측 요약문 :  excellent product
#
#
# 원문 :  thi product poor performer threw could shock even wet hand grabbing fence bought work beautifully charge electric poultry netting
# 실제 요약문 : mile ha cannot charge feet
# 예측 요약문 :  work
#
#
# 원문 :  wa happy getting thi product using subscribe save got word though longer available using option research try find another use subscribe save want get shipment way
# 실제 요약문 : get thi regularly via subscribe save
# 예측 요약문 :  great product
#
#
# 원문 :  bunch flax seed sealed plastic bag grind put morning oatmeal nice source fiber good fat barry farm wa great alway really liking idea flax seed diet
# 실제 요약문 : good stuff
# 예측 요약문 :  flax seed
#
#
# 원문 :  wa pleasantly surprised thi granola ha healthy ingredient use atop yogurt give yogurt little crunch would imagine would make great breakfast cereal well ordering
# 실제 요약문 : healthy addition yogurt
# 예측 요약문 :  great granola
#
#
# 원문 :  service wa great tea boxe came perfectly wrapped tea taste great shared enjoyed also thank
# 실제 요약문 : great tea
# 예측 요약문 :  great tea
#
#
# 원문 :  buy thi product old liquor gone buy thi product company fresh shall go back
# 실제 요약문 : old product
# 예측 요약문 :  old day
#
#
# 원문 :  big hit little granddog loved would buy never seen circle shape
# 실제 요약문 : dingo chew
# 예측 요약문 :  great gift
#
#
# 원문 :  say taste bland sweet juicy ha peculiar taste something would recommend buy
# 실제 요약문 : would buy
# 예측 요약문 :  taste like cardboard
#
#
# 원문 :  new puppy love thi chew bone toy ha week thi perfect would buy another one
# 실제 요약문 : puppy happy hi new chew bone
# 예측 요약문 :  puppy love
#
#
# 원문 :  thi coffee true name actually smell taste like traditional chocolate glazed cake like doughnut unlike donut house flavored varietie thi one actually taste good smell brewing light roast low acidity bitternes thi blend find need even les sugar per cup usually use achieve sweetnes great coffee
# 실제 요약문 : nice flavor
# 예측 요약문 :  smell like coffee
#
#
# 원문 :  wa happy received thi plant however died purchased several plant company died
# 실제 요약문 : disappointed
# 예측 요약문 :  plant
#
#
# 원문 :  think coffee experience beverage say thi stuff unique flavor one really work cannot wait try flavor
# 실제 요약문 : fun yummy flavor
# 예측 요약문 :  great coffee
#
#
# 원문 :  usually big fan herbal tea beverage thi seriously disgusting drink wa could brewed actually take sip smelling odor even five year old smelled said would want drink wa correct one sip wa enough would never ever pay money thi drink would happy never another taste
# 실제 요약문 : nasty
# 예측 요약문 :  thi tea
#
#
# 원문 :  thi particular green flavor monster good tasting find drinking taste never previously done energy drink whenever need start day sunrise thi energy drink choice
# 실제 요약문 : favorite energy drink
# 예측 요약문 :  best energy drink
#
#
# 원문 :  bought thi son wa gluten free diet could read ingredient bought name rice received wa made rice gluten called company said thi name brand oriental cracker
# 실제 요약문 : rice craker
# 예측 요약문 :  gluten free
#
#
# 원문 :  hi awesome favorite gift cannot stop looking best low price look awesome much fun never seen perfect gift would love want give friend mis thi fantastic bargain awesome gift
# 실제 요약문 : bonsai garden
# 예측 요약문 :  amazing
#
#
# 원문 :  stacy produce good pita chip thi one exception great take trip
# 실제 요약문 : good chip
# 예측 요약문 :  great chip
#
#
# 원문 :  feeding cat friskie two year grew concerned quality food one cat became obese dull fur little energy research grain free food switched wellnes core gave older cat urinary tract infection due high vitamin content switched thi formula see wonderful cat happy healthy full energy also much cheaper wellnes slightly expensive friskie worth
# 실제 요약문 : wonderful food
# 예측 요약문 :  best cat food
#
#
# 원문 :  wife make shepard pie thi wholesome taste good
# 실제 요약문 : excellent quality
# 예측 요약문 :  good stuff
#
#
# 원문 :  dog managed chew threw rubber tug les second said cannot say toy total los turned leftover part upside jug fairly effective slowing food treat inside keep mine amused long food
# 실제 요약문 : quick fix
# 예측 요약문 :  dog doe like
#
#
# 원문 :  discovered quinoa recently read health benefit great substitute rice couscou ha substance thi great value quinoa much cheaper local grocery
# 실제 요약문 : excellent value
# 예측 요약문 :  quinoa
#
#
# 원문 :  trouble acquiring thi coffee since moving north dakota several year like yuban flavor strong bitter may pay bit take amount coffee compared standard brand cost even bit lower also find yuban doe tend get burnt flavor left warmer extended time recommend yuban anyone enjoy coffee character
# 실제 요약문 : great product
# 예측 요약문 :  coffee
#
#
# 원문 :  truly never tasted honey character thi honey ha wa bit shocked spend acquire impossible go back average store bought honey side side taste test clover honey make believer anyone
# 실제 요약문 : nothing compare
# 예측 요약문 :  best honey
#
#
# 원문 :  thi best sodium free seasoning ever tasted enjoying egg meat carolyn california
# 실제 요약문 : sodium free seasoning
# 예측 요약문 :  love thi product
#
#
# 원문 :  thi great popcorn great source vitamin thi good stuff careful get brand waste money deliciou
# 실제 요약문 : fast delivery
# 예측 요약문 :  great popcorn
#
#
# 원문 :  miniature allergic wheat one seriously weight find wheat free healthy dog food hard time finding something found extremly expensive dog love thi food ha great ingredient also small piece dog eat thank making thi great product
# 실제 요약문 : one healthy weight wheat
# 예측 요약문 :  great dog food
#
#
# 원문 :  great keep freezer little peppery much add additional topping like necessary prepare perforated pan lower shelf oven like crispy crust add min cooking time
# 실제 요약문 : delicioiu easy prepare
# 예측 요약문 :  easy pizza crust
#
#
# 원문 :  cant figure gerber nd pea hard find store see something green alway green bean go pea much house child thi way going buy box compact remove top leave stored right box save ton room kitchen rather tipping cupboard one surprising thing also discovered cat ha low appetite love thi simple pea baby food ha healthy baby real treat pet good stuff
# 실제 요약문 : love multi pack
# 예측 요약문 :  great product
#
#
# 원문 :  carton arrived completely melted gues wa stored non air conditioned environment transit company mark product perishable wa awful never unles freezing weather
# 실제 요약문 : order dead winter
# 예측 요약문 :  melted
#
#
# 원문 :  bought gift wa dismayed discover description amazon prominently clearly describe chocolate covered espresso bean thi description appeared nowhere package package big letter read espresso chocolate blend asked people gifted like told tasty basically three different kind chocolate crunchy bit espresso bean mixed want espresso chocolate confection looking chocolate covered espresso bean look elsewhere
# 실제 요약문 : say
# 예측 요약문 :  chocolate bean
#
#
# 원문 :  like lot ajika condiment line organic glas jar plastic containing spice additive rated star however wa looking extract sure thi turmeric ha benefit holistic say think label jar
# 실제 요약문 : good organic turmeric
# 예측 요약문 :  good quality
#
#
# 원문 :  let face celiac disease free limited eat wa diagnosed loved pretzel nothing free taste good real thing thi product come close eat every day buy product case would highly recommend anyone cannot eat try thi product case life saver
# 실제 요약문 : free
# 예측 요약문 :  best gluten free pretzel
#
#
# 원문 :  eating lawry spaghetti sauce since childhood cook like add stuff great add onion teaspoon sugar heavy dash red wine garlic along ground sirloin fast easy deliciou
# 실제 요약문 : deliciou classic
# 예측 요약문 :  love thi sauce
#
#
# 원문 :  cannot find local grocer carry thi ordered pack ago boxe fine ala longer available directly amazon seller want almost absurd
# 실제 요약문 : said thank goodnes amazon
# 예측 요약문 :  amazon ha
#
#
# 원문 :  good jerky overall maybe people earlier got bad batch little salty overwhelming bbq flavor taste good jerky soft chewy cut big piece cant beat price
# 실제 요약문 : good stuff
# 예측 요약문 :  good jerky
#
#
# 원문 :  dog love thi food good best thing much waste pick would recommend thi dog food everyone
# 실제 요약문 : dog
# 예측 요약문 :  dog love
#
#
# 원문 :  received pink pure himalayan salt wa surprised arrived extremely well packed tried ha much much deliciou taste kosher sea salt buying using highly recommend thi salt anyone ha sitting fence wondering whether try
# 실제 요약문 : forget sea salt using
# 예측 요약문 :  great salt
#
#
# 원문 :  item ordered wa expected wa preserve preserve would reccomend thi item anyone receive hero quince preserve notify thank
# 실제 요약문 : preserve
# 예측 요약문 :  wrong item
#
#
# 원문 :  ha decent taste taste nothing like outback seasoning even close even similar sure review say false name doe equal real thing
# 실제 요약문 : ok
# 예측 요약문 :  taste like real thing
#
#
# 원문 :  buy thi locally farmer market health food type store run price nicely flavored store well cannot beat price note blend high quality evoo italy spain greece looking estate bottled least single sourced stuff thi however think good better higher priced single sourced evoo find pas evoo really good
# 실제 요약문 : awesome stuff
# 예측 요약문 :  good quality
#
#
# 원문 :  preface thi saying vegan eat meat said looking clean diet needed quick easy lunch make work would taste good enough would running hamburger stand also want eat something full kind dangerou chemical wanted fairly inexpensive saw little soup cup thing hannaford maine read ingredient fit bill bought different varietie trying lentil couscou first pleasantly surprised thought something wa low sodium vegan might bland really yummy flavorful well done might buy case
# 실제 요약문 : really yummy
# 예측 요약문 :  pretty good
#
#
# 원문 :  ha since koolaid remember wa younger mom like buy sold packet add sugar want drinking sugar koolaid come tub sugar already included much easier deal option make one glas time rather create whole pitcher add sugar big fan peach flavor thi peach mango koolaid exception taste great perfect blend mango versu peach love add amount powder prefer someone else make glas time add amount powder like
# 실제 요약문 : yum
# 예측 요약문 :  love thi stuff
#
#
# 원문 :  price doubled much ounce boxe company greedy use buy thi regularly
# 실제 요약문 : overpriced
# 예측 요약문 :  price
#
#
# 원문 :  picture ha peanut butter got strawberry fan also smaller one normally get store fresh part like could write cute note stick bf lunch thought wa fan ha
# 실제 요약문 : wa thought
# 예측 요약문 :  peanut butter
#
#
# 원문 :  wa little concerned buying bulk reading previou review concern unfounded wa delighted product wa musty taste bag taste exactly buy smaller snack package grocery store thi great product sweet crunchy way les expensive purchase thi way
# 실제 요약문 : excellent product
# 예측 요약문 :  great product
#
#
# 원문 :  local healthfood store sell thi nearly double subscribe save cost could believe thi good quality organic maple sugar price best find anywhere use thi sparingly still expensive sweetener ha vitamin mineral doe deplete body digest
# 실제 요약문 : great price
# 예측 요약문 :  great value
#
#
# 원문 :  thi particular auntie chun ha gram fat gram saturated fat thi much healthier nissan fried ramen simply asian noodle gram fat one gram per whole serving serving size taste vibrant lovely thi auntie chun personally buying auntie chun wanted interested nutrition notice thi startling difference quality product taste essentially auntie chun simply asian get teriyaki noodle pad thai simply asian healthy living
# 실제 요약문 : fatty caution compare simply asian
# 예측 요약문 :  miracle noodle
#
#
# 원문 :  thi fantastic high quality product irresistible picky little eater also ha good moisture content
# 실제 요약문 : picky little eater cannot resist
# 예측 요약문 :  best
#
#
# 원문 :  looking nutrition bar wa high protein high fat sugar many month bingo thi one could live thing
# 실제 요약문 : deliciou nutritiou
# 예측 요약문 :  great protein bar
#
#
# 원문 :  thi first experience kefir anything compare happy purchase arrived promised ha worked great instruction recipe helpful would recommend thi product
# 실제 요약문 : great purchase
# 예측 요약문 :  kefir kefir
#
#
# 원문 :  thi alcohol removed wine really good even family member able drink impressed body care quality put product make people want continue using something definetly continue using
# 실제 요약문 : something drink
# 예측 요약문 :  good product
#
#
# 원문 :  got oz bag cafeteria enjoyed every bite since wanted stay away potato chip wanted snack crunch wa disappointed chip good crunchy
# 실제 요약문 : like lot
# 예측 요약문 :  good
#
#
# 원문 :  dextrose shipped quickly arrived well delivery estimate bag received identical one pictured powder soft fine fresh course wa looking
# 실제 요약문 : good product good price
# 예측 요약문 :  great product
#
#
# 원문 :  wa pleasantly surprised spice thi flavor ramen tried thi point wa chicken beef chili flavor wa nice change recommend long like spicy dishe
# 실제 요약문 : nice change
# 예측 요약문 :  spicy
#
#
# 원문 :  like try different coffee switch lot one month another wa gevalia kick fell love thi particular roast buy gevalia month come back season
# 실제 요약문 : excellent
# 예측 요약문 :  love thi coffee
#
#
# 원문 :  sweet cinnamon flavor crispy thin eat think smile interesting snack idea underlying concept product cocoa alkalized way preserving natural antioxidant well good still come taste right like chocolate cinnamon found pretty good texture little different mind thing would change would make piece bigger wish stick single serving would stuck counting piece triple size make serving come around would like snack cracker otherwise think hit looking healthy sweet snack like chocolate cinnamon give try taste start chocolate cinnamon finish
# 실제 요약문 : tasty healthy snack
# 예측 요약문 :  sweet treat
#
#
# 원문 :  bought thi mix amazon wa stonewall kitchen mix easy review talk thing reviewing thing relate taste flavor difficult say anything like best effort taste texture color used waffle mix cannot speak pancake taste waffle taste wa malty also waffle dense wa hard get inside cooked outside look perfectly golden stonewall kitchen win hand
# 실제 요약문 : meh
# 예측 요약문 :  best waffle mix
#
#
# 원문 :  save special treat dog bit pricey love much willingly go crate get one
# 실제 요약문 : dog love
# 예측 요약문 :  dog love
#
#
# 원문 :  crema di balsamic regular imported italy sublime thick sweet sour balsamic vinegar enhance food part family tradition handed recipe enjoy cooking whenever possible also wonderful italian greek spanish dishe want add dash tuna steak quick mozzarella sliced garden tomato amazing thi bit pricey worth every penny
# 실제 요약문 : exquisite balsamic cream
# 예측 요약문 :  best balsamic vinegar
#
#
# 원문 :  year old liked thi cookie could handle eating day wa overly sweet personally care taste wa full preservative wa thing standard home stored baked cookie interesting able keep chocolate soft inside cookie add value cookie cookie wa soft crumbly lot chocolate inside overall taste wa unnatural enjoy something recommend
# 실제 요약문 : unnatural taste
# 예측 요약문 :  ok
#
#
# 원문 :  thi tree showed quickly wa well packaged wa watered wa wrapped wa well hydrated arrived see damage wa outside two day great yellow leave ha new growth would order stopping store next time area looking tree add collection send one mother mother law
# 실제 요약문 : like picture better wa real got
# 예측 요약문 :  great gift
#
#
# 원문 :  massage therapist alway little treat client done session people love ghiradelli square minty one far favorite nice bite sized treat decent dark chocolate balanced sweetish mint filling
# 실제 요약문 : great stand
# 예측 요약문 :  deliciou
#
#
# 원문 :  wa pleasantly surprised flavor truffle among best chocolate milk chocolate ha wonderful light center crispie hazelnut flavor one gold foil mild good dark chocolate dark chocolate nib wa biggest surprise usually like chocolate darker chocolate chip thi really good deep chocolate flavor nib pleasant addition order gift road tested update reordered one container wa badly damaged broken enough protective packing material cardboard holder bottom wa placed top package damage happened packing proces shipment
# 실제 요약문 : outstanding chocolate
# 예측 요약문 :  deliciou
#
#
# 원문 :  thi tellicherry pepper wa fresh aromatic packaged well thi grind beautifully add incredibly complex deliciou flavor savory dishe get pepper mill loosen screw course grind tighten screw fine grind excellent quality spice spicy world ha ever disappointed
# 실제 요약문 : excellent pepper
# 예측 요약문 :  fresh flavorful
#
#
# 원문 :  absolutely love disc twining chai tea latte cup every day whenever relaxing reading book cheap sure better paying starbuck
# 실제 요약문 : twining chai tea latte amazon
# 예측 요약문 :  chai latte
#
#
# 원문 :  local pet store recommended help aging dog seem help little pain getting slow moving say thi best price found internet search almost half price local pet store
# 실제 요약문 : help dog
# 예측 요약문 :  good price
#
#
# 원문 :  bought infuser need loose tea go tried white ayurvedic chai tea love gone back tried got shipment friday tried yet
# 실제 요약문 : love thi tea
# 예측 요약문 :  chai tea
#
#
# 원문 :  herb de provence thi true product bear label great french item story recipe behind anyone using thi product doe know story definitely worth reading thank carrying thi product original crock large size use almost everything sometime tiny pinch several large pinche voila du roy
# 실제 요약문 : true one original
# 예측 요약문 :  best herb
#
#
# 원문 :  thi tea work tasted great wa piping hot fresh however make morning sicknes go away stopped using tea bag actually made really sick tea cooled could drink wa really hot gues different everyone work definitely go work
# 실제 요약문 : tea work
# 예측 요약문 :  work
#
#
# 원문 :  popcorn arrived well packaged reasonable time unfortunately phoenix weather chocolate zebra popcorn melted refused fault seller popcorn tasted fine provided multiple gift giving
# 실제 요약문 : deliciou delivery
# 예측 요약문 :  popcorn
#
#
# 원문 :  sriracha ha become daily staple household put everything hot learn limit try thi great egg meat chicken use steamed pork bun even tried hot dog day nice thi price right two ten buck start cannot stop
# 실제 요약문 : thi alway cupboard
# 예측 요약문 :  love thi stuff
#
#
# 원문 :  got keurig coffee maker tried brew available cup thought might settle les bold coffee based review amazon com went coffee people jet fuel pleased couple year subscribe save option great pretty good deal
# 실제 요약문 : boldest cup found
# 예측 요약문 :  great coffee
#
#
# 원문 :  ordered thi one azalea tabletop bonsai really cute little tree arrived great shape included item blue pot white gravel drip tray small gravel top would probably make cool gift anyone remotely interested plant
# 실제 요약문 : neat little tree
# 예측 요약문 :  nice little tree
#
#
# 원문 :  thi popcorn deliciou sharing one bag two people highly recommend eat whole bag would recommend thi ha much sodium fat taste personal opinion really like natural popcorn thi wa natural enough
# 실제 요약문 : deliciou salty
# 예측 요약문 :  deliciou
#
#
# 원문 :  trying reduce amount sugary snack life get jone something sweet really hit spot like typical raisin get box grocery store soft bit sticky nice sweet chewines really satisfie craving
# 실제 요약문 : tos boxed
# 예측 요약문 :  sweet treat
#
#
# 원문 :  sure previou reviewer said children could eat hard month old doe molar eat two time love tasted rather tasteles kid like care purchased whim supermarket son wa month liked fact wa lot sugar also organic contain whole grain
# 실제 요약문 : month old love
# 예측 요약문 :  kid love
#
#
# 원문 :  got sick sending flower wanted sister experience something different decided thi broadway basketeer allergic salt nut product thi ha many great dried fruit called wa happy said wa huge husband going love eating thi great basket allergie food product people love getting thing eat thi product sister ha even used empty box craft
# 실제 요약문 : fruit basket instead flower
# 예측 요약문 :  great product
#
#
# 원문 :  alway skeptical high fiber bar fearing tasteles hard swallow kellogg bar nice surprise good chocolate flavor nice blend crunchy sweet quite filling though little high fat fact calorie fiber helped buying
# 실제 요약문 : pretty tasty lot fiber
# 예측 요약문 :  good
#
#
# 원문 :  low acid diet thi coffee work used year buy bean grind fresh
# 실제 요약문 : low acid
# 예측 요약문 :  low acid coffee substitute
#
#
# 원문 :  taste similar high quality thi mix easy use wa happy product
# 실제 요약문 : deliciou dangerou
# 예측 요약문 :  great product
#
#
# 원문 :  ordered packet carry one daily taste great work great pleased thank
# 실제 요약문 : dressing
# 예측 요약문 :  great product
#
#
# 원문 :  thi stuff work great control alcohol content drynes longer brew higher alcohol content get time juice get dryer lack sugar want higher alcohol content want stay sweeter add cup sugar juice beforehand shake real good add mix brew day two longer initial hour taste brew change pretty dramatically day day taste test go along also make sure remove cup juice bottle brew thi prevent problem push rubber cap onto bottle
# 실제 요약문 : work promised
# 예측 요약문 :  great taste
#
#
# 원문 :  picky coffee make latte senseo god sake price wa good bought thi one french vanilla bad thi one wa worst wa bitter plain bad tasting thi first brand tried coffee ha poor quality acros board trying finish thi think might throw rest away bad note review wa supposed wolfgang puck sumatra look like guy mistakenly posted
# 실제 요약문 : bitter horrible
# 예측 요약문 :  worst coffee ever
#
#
# 원문 :  found yogi tea local grocery store began amazing love affair love tea thi stomach ease one perfect time feeling hot south belly button
# 실제 요약문 : awesome tea
# 예측 요약문 :  love thi tea
#
#
# 원문 :  thi good taste like real lemon juice go pretty quickly putting lemon juice every glas water drink
# 실제 요약문 : taste like lemon juice
# 예측 요약문 :  lemon lime
#
#
# 원문 :  trying give son food common allergen age one search snack dairy wheat soy found puff contain rice sweet potato apple juice thing month old son ha tried allergic love puff love made organic ingredient highly recommend
# 실제 요약문 : puff son eat
# 예측 요약문 :  kid love
#
#
# 원문 :  first purchased variety pack thi product costco black cherry wa alway flavor wa first son pretty much live thi beverage happy like thi better soda since bit healthier happy able get thi amazon subscribe save even pay shipping
# 실제 요약문 : favorite flavor
# 예측 요약문 :  love thi product
#
#
# 원문 :  thi wa good cranberry bread worth money would buy came time wa easy make never cranberry bread thi bread wa different good buy try bread cook company everyone like
# 실제 요약문 : good bread
# 예측 요약문 :  good bread
#
#
# 원문 :  thi peanut butter next impossible find area wa glad find amazon promo thi peanut butter extremely picky toddler eat say ha great taste thi peanut butter awesome super deliciou see actual peanut halve chunk love
# 실제 요약문 : best tasting peanut butter
# 예측 요약문 :  best peanut butter ever
#
#
# 원문 :  cafe thi product move quickly people really like brand twining subscribe save nice benefit busy busines owner one les thing inventory weekly
# 실제 요약문 : good busines
# 예측 요약문 :  great coffee
#
#
# 원문 :  fragile pup bit right rubber rope think lasted minute granted adolescent still higher hope sticking kong
# 실제 요약문 : fragile
# 예측 요약문 :  bad
#
#
# 원문 :  freshest date ever purchased deliciou favorite family make trail mix
# 실제 요약문 : freshest date
# 예측 요약문 :  fresh
#
#
# 원문 :  ring much sturdier one past break easily kid alway like ring day hit mis fun day year old
# 실제 요약문 : car party ring
# 예측 요약문 :  great birthday party
#
#
# 원문 :  maltese dog ha wellnes food two year love taste feel good feeding ingredient sound ideal healthy ha super healthy ha great bathroom schedule overall seem like happy well fed pup worth price see feeling looking great love
# 실제 요약문 : great food
# 예측 요약문 :  great dog food
#
#
# 원문 :  love thi soup like alot dr mcdougall soup watch cooking cut time full power also let sit minute soften bean cooking cooking second power soften time heat
# 실제 요약문 : great taste direction
# 예측 요약문 :  great soup
#
#
# 원문 :  going get sugar cereal ought least taste great getting pleasure exchange thi cereal doe taste good cannot see reason recommend
# 실제 요약문 : good
# 예측 요약문 :  taste great
#
#
# 원문 :  lime flavored spite red color indicating poor quality control wonder life saver seldom found store anymore
# 실제 요약문 : bad batch
# 예측 요약문 :  lime chile lime
#
#
# 원문 :  spent year area although several brand spiedie sauce thi absolutely best marinate meat day flavor richer fantastic highly recommend thi anyone enjoy
# 실제 요약문 : best sauce
# 예측 요약문 :  best steak sauce ever
#
#
# 원문 :  thi excellent value amazon three one pound bag also unlike buying five pound bulk bag stay fresh longer love thi particular configuration haribo gold bear portion control provide mini bag contain calorie six eight mini bear per tiny bag thu thi perfect size pack lunch bag hide purse sneak movie gummy bear may perfect health food mini baggie yummy gold bear sensible sweet treat choice calorie consciou
# 실제 요약문 : excellent value
# 예측 요약문 :  deliciou
#
#
# 원문 :  recently spoiled fresh roasted coffee local roaster wa intrigued positive review anyway thi stuff wa better sit grocery shelve month month waiting waiting going stale every passing day favor buy fresh whole bean coffee like dark brazilian santo whole bean coffee pound bag grind burr grinder brew manual method coffee nirvana never buy thi stuff
# 실제 요약문 : thi great coffee
# 예측 요약문 :  stale
#
#
# 원문 :  used thi product alot back home could find halal anywhere close came hit upon thi page chance ordered one package arrived day later good condition load time left expiry satisfied ordering thi item frequently
# 실제 요약문 : nostalgia
# 예측 요약문 :  great product
#
#
# 원문 :  thi convenient coffee refrigerated served cool ice flavorful take iced coffee also contain many chemical may like coffee brand superior coffee comfortable additive thi brand also pretty sweet depending taste may like dislike thi factor
# 실제 요약문 : sweeter tasting iced coffee
# 예측 요약문 :  nice coffee
#
#
# 원문 :  directly product detail purchased received product wa since received clearly ordered returning product multiple listing similar product ensure discription correct product detail product dimension inche pound
# 실제 요약문 : nylabone
# 예측 요약문 :  product pictured
#
#
# 원문 :  great choice limiting carbohydrate processed food still need little crunch food great either themselve salad casserole vegetable soup perfect size cannot stop putting hand back larger bag chip
# 실제 요약문 : happy choice
# 예측 요약문 :  great snack
#
#
# 원문 :  dog like product long lasting chew mild chewer fan chew take hour go large chew gave thi large aggressive chewer would gone time flat since picky eater enjoy continue purchase treat price also ridiculously high get especially since ingredient simple basic
# 실제 요약문 : ok
# 예측 요약문 :  dog love
#
#
# 원문 :  thi excellent green tea little spicy flavorful green tea good even mis morning coffee helping children buy tea district children tribute tea
# 실제 요약문 : tasty tea
# 예측 요약문 :  green tea
#
#
# 원문 :  loma linda swis stake product great hurry open heat hearty meal mashed potatoe vegetable salad like use however recipe call item stretch make pattie casserole dish bake meal church work quite well using base manhattan meatles meatball pattie
# 실제 요약문 : swis stake review
# 예측 요약문 :  great product
#
#
# 원문 :  thi favorite flavor primal strip like ordered thi one last since sounded weird great lime flavor strong texture good lowest calorie line excellent guilt snack
# 실제 요약문 : great snack protein calorie
# 예측 요약문 :  love thi stuff
#
#
# 원문 :  although flavor good doe last long flavor leave gum unpleasant chew
# 실제 요약문 : flavor let
# 예측 요약문 :  good flavor
#
#
# 원문 :  barilla whole grain mezze penne tomato basil sauce incredible need refrigeration tos kitchen cabinet desk work leave briefcase quick fix taking one minute heat microwave eating know deliciou something nuke scarf fill belly ounce size filling add salad bread really hungry pasta ha nice al dente chew sauce really flavorful love thi meal calorie made healthier whole grain pasta definitely buy keep hand need something fast flavorful
# 실제 요약문 : fast flavorful
# 예측 요약문 :  great quick meal
#
#
# 원문 :  close friend mine work brought bag wasabi pea take long get addicted like horseradish going love wasabi pea bite come first handful great snack work also help cleanse sinuse wa able find half thi size local meijer store wa happy see amazon carrie brand bigger also purchase four pack plenty stock home work
# 실제 요약문 : wasabi pea
# 예측 요약문 :  wasabi pea
#
#
# 원문 :  get grocery store price cheaper realize oz jar wa clearly laid ordered likely would bought review seem natural
# 실제 요약문 : small container
# 예측 요약문 :  price
#
#
# 원문 :  thi healthy diet dog leave bowl dog snack combine diet wet food great price delivered door
# 실제 요약문 : dog love thi food
# 예측 요약문 :  dog love
#
#
# 원문 :  super tasty great consistency hardy bar tartnes cranberrie play great balance nut grain perfect cal snack
# 실제 요약문 : great
# 예측 요약문 :  deliciou
#
#
# 원문 :  add small amount millet homemade cat food recipe make week thi brand excellent seller ship quickly
# 실제 요약문 : nice product quick shipping
# 예측 요약문 :  excellent product
#
#
# 원문 :  unles dog outside dog live outside would gnawing yard beef tendon stink smell permeate entire house reason alone would difficult time purchasing odor horrific
# 실제 요약문 : stinky tendon
# 예측 요약문 :  dog hate
#
#
# 원문 :  four jam come tucked simple white square cardboard carton green label way easy wrap add nice ribbon actually split set two hostes gift wa glad see jam wa fully labeled could stand alone without box recipient mentioned much enjoyed jam commented flavor quality good pick
# 실제 요약문 : nice product nice gift giving option
# 예측 요약문 :  jam
#
#
# 원문 :  wow michael season cheese curl used favorite snack however last shipment received wa terrible possible explanation strange taste thi order sure bad cheese curl typically problem still owner bag yucky curl continue support thi natural food company bag time
# 실제 요약문 : good bad
# 예측 요약문 :  cheese
#
#
# 원문 :  bought thinking made people make sour patch kid green apple surely gonna sour wrong really want good sour candy like sour patch kid waste money thi tiny hint green apple enough taste love good tart granny smith apple even come close stick sour patch kid like sour
# 실제 요약문 : sour
# 예측 요약문 :  sour sour
#
#
# 원문 :  thi mix made deliciou light belgian waffle used caution since serving first time company turned great
# 실제 요약문 : great waffle
# 예측 요약문 :  deliciou
#
#
# 원문 :  glad found nori sheet organic free toxin ocean cut strip onto food stuffed wrapped roll without falling apart
# 실제 요약문 : organic nori sheet
# 예측 요약문 :  fresh
#
#
# 원문 :  absolutely love thi rub hooked year ha great kick found great beef even used batter frying chicken making country fried steak ever chance try john restaurant memphi memphi may world championship bbq cooking contest already know talking
# 실제 요약문 : must
# 예측 요약문 :  best rub ever
#
#
# 원문 :  love honey stinger gel sweet almond cherry flavor better peanut butter like saltier peanut flavor
# 실제 요약문 : sweet
# 예측 요약문 :  good
#
#
# 원문 :  coffee taste great still bit expensive considering coffee trying buy decent supermarket instant coffee discovered thi worth price
# 실제 요약문 : good stuff
# 예측 요약문 :  great coffee
#
#
# 원문 :  bake often usually bake scratch felt lazy tonight thought would try thi mix fiance agreed wa worst cake either one ever live eaten took one bite handed hi plate straight back exact word take thi sight thi cake dense heavy chewy eggy yet dry time ha strange unpleasant texture light beside texture taste wa also horrible fiance nailed next day said cake reminded lot cornbread bad cornbread nasty would feed thi cake dog
# 실제 요약문 : worst cake ever eaten live
# 예측 요약문 :  waste money
#
#
# 원문 :  picked local costco good deal great tasting healthy sardine doe anybody know much olive oil fish canned tablespoon two cannot find information tell much actual olive oil want use information planning
# 실제 요약문 : tasty
# 예측 요약문 :  good product
#
#
# 원문 :  thi pretty good oil taste good nice texture smell fresh experienced superior coconut brand like nutiva though carry quality product im dissapointed blown away probably purchase eventually
# 실제 요약문 : pretty good
# 예측 요약문 :  good quality
#
#
# 원문 :  read glowing review check date cookie year old taste way perhap would better soaked milk however doubt revive like eating cardboard hint stale spice waste money tin holiday mean three year old
# 실제 요약문 : might good two year ago
# 예측 요약문 :  stale
#
#
# 원문 :  product arrived perfectly tact time good couple month expiration date
# 실제 요약문 : problem
# 예측 요약문 :  great product
#
#
# 원문 :  thi nd bottle magical garlic seasoning really much use meat make best garlic bread ever evoo yummy
# 실제 요약문 : life changing
# 예측 요약문 :  garlic garlic seasoning
#
#
# 원문 :  thi favorite tea tea doe great job love order larger size drink tea daily delivery wa quick price wa right
# 실제 요약문 : time favorite
# 예측 요약문 :  great tea
#
#
# 원문 :  purchased thi item wife th birthday party little expensive good quality lot fun played pin tail donkey gave piece era candy player loved amazing candy brought back good memorie everyone
# 실제 요약문 : fun product wife th birthday
# 예측 요약문 :  great
#
#
# 원문 :  recently discovered thi product kid love new innovative format year old wa younger loved yogurt melt big kid refuse eat melt babie yo drop crunchy flavorful yogurt drop feel like candy super healthy individually packed throw pack purse go also keep box car kid cranky need light healthy snack meal
# 실제 요약문 : yummy healthy snack
# 예측 요약문 :  kid love
#
#
# 원문 :  dog love absolutely help hi hip joint year old lhasa apso joint problem since started using happy hip gone away hope one ever tell good
# 실제 요약문 : dogswell happy hip chicken banana
# 예측 요약문 :  happy hip
#
#
# 원문 :  ordered husband said okay like green mountain brand better next time order green mountain brand
# 실제 요약문 : good liked green mountain better
# 예측 요약문 :  green mountain
#
#
# 원문 :  absolutely love thi cereal cannot find anywhere incredibly frustrating annoying going post thi cereal poorly distributed indication anywhere discontinued available supermarket visit walmart
# 실제 요약문 : wonderful cereal
# 예측 요약문 :  cereal
#
#
# 원문 :  nabisco ha alway one favorite brand honey graham one favorite cookie cracker still fresh crispy wonderful flavor size packaging different like packaged individual pack great lunchboxe office desk quick snack like work cup hot tea sometime time real lunch great peanut butter nutella excellent fresh stack per box one considered serving thing one need careful easy open eat one entire snack pack calorie careful watch eat share pack
# 실제 요약문 : yum
# 예측 요약문 :  perfect size
#
#
# 원문 :  ordered wa super excited new flavor huge disappointment absolutely candy corn flavor price outrageou save money really want try go target available exclusively
# 실제 요약문 : skip
# 예측 요약문 :  disappointing
#
#
# 원문 :  wa never big fan coffee loved energy boost could put bitter taste would alway put ton sugar mine make drinkable calorie one beverage worth torani came thi deliciou sugar free zero calorie syrup drink coffee every morning love started six flavor assortment okay caramel favorite one buy regularly also love amazon sell pack decent price
# 실제 요약문 : cannot believe ha zero calorie
# 예측 요약문 :  great coffee
#
#
# 원문 :  brown almond roca deliciou given gift many close friend family seem like lot highly recommend sweet tooth
# 실제 요약문 : love almond roca
# 예측 요약문 :  deliciou
#
#
# 원문 :  thi ramen good also bought neoguri also good choice like seafood would highly recommend thi microwave well use pyrex deployed ship wa sent pretty quick none ramen wa damaged spicy definitely seriously spicy cook minimal water stay way love buy pretty much highlight day
# 실제 요약문 : fantastic
# 예측 요약문 :  best ramen ever
#
#
# 원문 :  wolfgang puck coffee chef columbian decaf fantastic deliciou definitely recommend thi product anyone want great cup coffee
# 실제 요약문 : wonderful cup
# 예측 요약문 :  deliciou
#
#
# 원문 :  often come bad mouth amazon thi product overpriced imo buy co ounce bag mean one twice price crazy
# 실제 요약문 : great overpriced unfortunately
# 예측 요약문 :  overpriced
#
#
# 원문 :  thi solixir ha type flavor energy drink beware dont like yellow fizzy type drink prefer chamomile version solixir
# 실제 요약문 : ok solixir taste like energy drink
# 예측 요약문 :  ok
#
#
# 원문 :  wa recently introduced thi pinot noir excellent thi wine fruity like bitter dark type thi one bring buy east coast problem though worth every penny
# 실제 요약문 : best pinot noir taste
# 예측 요약문 :  best wine
#
#
# 원문 :  old newton gotten cookie light tangy flavor sweet cranberry citru blend terrific combination definitely prefer old fig newton one complaint weak packaging thin plastic tray doe hold well shipping handling good portion cookie crumbled piece
# 실제 요약문 : great cookie bad packaging
# 예측 요약문 :  nice little sweet
#
#
# 원문 :  thi canned tuna eat packed olive oil nothing else come close
# 실제 요약문 : canned tuna eat
# 예측 요약문 :  tuna
#
#
# 원문 :  got thi honey health benefit wa worried packaging issue discussed several review thi problem ha solved plastic lid wa attached base piece plastic whole jar wa tightly wrapped bubble wrap
# 실제 요약문 : package problem ha solved
# 예측 요약문 :  good product
#
#
# 원문 :  kitten senior love thi food house eat fruit piece first healthy happy cat using thi product year love
# 실제 요약문 : cat love thi food
# 예측 요약문 :  great product
#
#
# 원문 :  dog love quite expensive think way priced get special occasion sell store like petsmart petco
# 실제 요약문 : great chew
# 예측 요약문 :  dog love
#
#
# 원문 :  thi resemble soft chewy coconutty oatmeal cookie think coconut part description sweetened coconut well agave folk like taste coconut bar hit rest family well price say comparable clif odwalla similar bar typically apiece something like quaker chewy granola bar think competitively priced get
# 실제 요약문 : yummy coconutty filling
# 예측 요약문 :  chewy chewy
#
#
# 원문 :  wife love thi latte mocha cheap grinder never justice want spring new one thi pre ground espresso ha answer
# 실제 요약문 : great espresso jiffy
# 예측 요약문 :  great coffee
#
#
# 원문 :  read lot review internet dry dog food thi one wa highly rated grain free may expensive well worth price standard poodle picky hi food food hound least liked immediately
# 실제 요약문 : good well balanced dry food
# 예측 요약문 :  dog love
#
#
# 원문 :  brazil thi true version made scratch one love love buy boxe sell half boxe neighbor friend huge succes around keep buying whenever see available
# 실제 요약문 : good brazilian product
# 예측 요약문 :  best
#
#
# 원문 :  yellow lab stand head treat ha see red bag also love salmon oil
# 실제 요약문 : bella think best
# 예측 요약문 :  dog love
#
#
# 원문 :  big water drinker wanting try mio awhile easy use really care taste definitely ha strong taste someone drink diet drink regularly thi probably something like stick plain old water fresh lemon slice
# 실제 요약문 : ok
# 예측 요약문 :  taste like water
#
#
# 원문 :  thi stuff joke im afghanistan thought would something fellow marine get kick take thi stuff lightly hottest thing ive ever eaten far
# 실제 요약문 : wow
# 예측 요약문 :  hot
#
#
# 원문 :  waste money proflower horrible company quality price customer service much worse companie thinking placing order save time flush money toilet
# 실제 요약문 : ugh never going buy proflower
# 예측 요약문 :  waste money
#
#
# ...
#
#
# 원문 :  truly yummy applesauce convenient cup take work school also frequently mix baby oatmeal mo old daughter breakfast buy bulk shipped regularly using subscribe save way cheaper next cheapest organic applesauce found trader joe
# 실제 요약문 : deliciou nutritiou
# 예측 요약문 :  great product
#
#
# 원문 :  deliciou bad cannot find store wa getting sam club anymore
# 실제 요약문 : soooo good
# 예측 요약문 :  deliciou
#
#
# 원문 :  veri peri mild deliciou love extra kick sauce great flavor spicy sauce versatile try using pizza salad dressing marinade meat veggie
# 실제 요약문 : veri peri veri good
# 예측 요약문 :  love thi stuff
#
#
# 원문 :  love thi drink cut though year drinking became little aside thi drink god beat powered website wa lazy work site pumped celsiu got work good stuff unbeatable
# 실제 요약문 : celsiu eff
# 예측 요약문 :  love thi drink
#
#
# 원문 :  roasted peeled chestnut life since les time energy ordered jar already peeled tried lot different one found tasteful clean fresh
# 실제 요약문 : best chestnut ever
# 예측 요약문 :  chestnut roasted chestnut
#
#
# 원문 :  good better regular cappuccino les calorie rarely go starbuck anymore prefer
# 실제 요약문 : delicioso
# 예측 요약문 :  cappuccino
#
#
# 원문 :  picture package little misleading suggest morsel ha least couple flavor nugget peanutty goodnes attached fact flavor nugget quite bit one might expect clear whether actual peanut fragment thi cereal certainly deliciou quite crunchy crunchines last several minute even milk partner thought sweetnes wa right found lot nutty flavor thought wa little sweet without much nuttines kid certainly love thi even though enjoyed lot cannot give three star based rather dubiou nutritional value
# 실제 요약문 : doe look like package
# 예측 요약문 :  tasty
#
#
# 원문 :  price pound weight package flour total thi perhap outrageou food item available amazon com cannot think reason would order thi fashion pack flour cannot possibly run thi much store pay shipping little much need pack king arthur organic flour say thi good buy otherwise buy flour need store king arthur flour experience good get eat straight though see people try dangerou though flour king arthur brand supposed eaten straight bag
# 실제 요약문 : whole lotta flour goin
# 예측 요약문 :  expensive
#
#
# 원문 :  planted thi wheat day ago raised bed garden already inche tall also sprouted thi wheat sprout jar wa productive happy purchase
# 실제 요약문 : thi stuff grow fast garden
# 예측 요약문 :  wheat gras
#
#
# 원문 :  great product description spicy hot ha half crab love crab especially floating deliciou stew spicy hot nom nom nom really thi stuff amazing opposed anything drinkable tomato flavored entire life tried thi stuff wa hooked crab
# 실제 요약문 : mm half crab
# 예측 요약문 :  amazing
#
#
# 원문 :  ordered another package thi wonderful tea drink breakfast lunch dinner flavor really good drink thi tea without sugar month pregnant moment tea really help relax feel better especially long crazy day chasing year old around sit turn nice movie big cup thi wonderful rejuvenating tea like made blend healthy herb body mind lactation consultant midwife recommend yogi tea pregnant women also one nursing women help milk production
# 실제 요약문 : best tea pregnant
# 예측 요약문 :  thi tea great
#
#
# 원문 :  paid little case pumpkin normally would far ha met expectation really packed need something really smooth take mixing deliciou recipe made
# 실제 요약문 : love pumpkin
# 예측 요약문 :  pumpkin spice
#
#
# 원문 :  hot food junkie found chip local grocery store got addicted kept searching must trial run never return amazon fortunately palette sized order rather couple bag oh well thi simply nuclear face gastro potato chip ever snack aficionado like try half bag paying price
# 실제 요약문 : hottest earth
# 예측 요약문 :  best chip ever
#
#
# 원문 :  bought thi box husband easter gift wa excited opened loved old school candie everything wa fresh
# 실제 요약문 : pleased
# 예측 요약문 :  great gift
#
#
# 원문 :  alway great food option easier cooking fresh glas jar great service prompt never damaged jar highly recommend chestnut company
# 실제 요약문 : deliciou nutritiou
# 예측 요약문 :  great product
#
#
# 원문 :  peach slice taste real good really say much review say buying well worth money shipped rec time
# 실제 요약문 : peache
# 예측 요약문 :  peach tea
#
#
# 원문 :  happy found purchase line arrived perfect condition let sit couple day ripen family savored every deliciou bite another plu aroma guava amazing really made house fragrant definitely buy
# 실제 요약문 : deliciou
# 예측 요약문 :  deliciou
#
#
# 원문 :  much say ha said carbon golden malted waffle pancake mix using regular mix waffle pancake outstanding result stumbled upon natural mix frankly sure main difference regular mix natural mix kid around house seemed like brainer using natural waffle pancake still amazing natural still get request time kid daddy waffle daddy pancake needles say sticking carbon mix sticking natural
# 실제 요약문 : simply best
# 예측 요약문 :  best waffle mix
#
#
# 원문 :  good tea advertised pack thi pack thi single box amazon correct product description vendor amazon offer pack revolution tea dragon eye oolong tea count tea bag
# 실제 요약문 : good tea
# 예측 요약문 :  tea
#
#
# 원문 :  pet grain free diet really important thier total health seen difference bengal coat stool really goe crazy set bag near food switching got home work lb bag wa pulled shelf ripped ha never done food
# 실제 요약문 : best grain free food
# 예측 요약문 :  dog love
#
#
# 원문 :  received berry sport tablet timely manner started using right away tablet convienent powder mixe berry berry liciou
# 실제 요약문 : zym tablet travel
# 예측 요약문 :  great product
#
#
# 원문 :  great sampler set ha different type numi tea little box great esp giving friend try different kind issue buying thi bulk tea like pile particular one sitting cabinet
# 실제 요약문 : nice sampler
# 예측 요약문 :  great selection
#
#
# 원문 :  true puck organic soup bit high salt aside staple home winter order several case pre winter mid winter barley lentil husband favorite heartily eat
# 실제 요약문 : staple winter
# 예측 요약문 :  love thi soup
#
#
# 원문 :  like add voice several reviewer raved thi sauce wa skeptical first wa little put one reviewer said thi sauce tasted fishy ordered regretted one bit hot probably scale like bit fishy taste way overwhelming fact actually add flavor instead also ha bit sweet gingery flavor expected sauce thi corner world nutshell thi sauce awesome nice flavor nice heat goe well pretty much everything whether beef chicken fish veggie thi great around sauce staple kitchen
# 실제 요약문 : awesome sauce
# 예측 요약문 :  best sauce ever
#
#
# 원문 :  without exception everyone ha tasted thi tea ha loved hard core tea drinker experience tea garbage like lipton harney released cinnamon spice green tea also excellent drink wide range tea easily cup day special tea like lapsang souchong oolong black tea yet think overall favorite cinnamon spice green
# 실제 요약문 : one favorite tea
# 예측 요약문 :  bigelow cinnamon tea
#
#
# 원문 :  although unhealthy lot sodium soup make find alway good daughter sometime eat noodle side dish using flavor packet sometime make soup done add vegetable choose enjoy easy hold hot microwave
# 실제 요약문 : maruchan instant lunch roast chicken
# 예측 요약문 :  great soup
#
#
# 원문 :  great flavored oatmeal snack healthy dessert product chocolate peanut butter flavor amount sugar reasonable highly recommended
# 실제 요약문 : great oatmeal
# 예측 요약문 :  great snack
#
#
# 원문 :  amazon rock ordered case taste like blackeye pea much better cajun eat pork chop rice gravy season onion bacon granddaughter love vegan ha try make homey food anyway amazon thank awesomenes
# 실제 요약문 : taste like home
# 예측 요약문 :  best
#
#
# 원문 :  rusk better product thi product wa close slightly cheaper anyone looking decent decent price ha found wanted
# 실제 요약문 : good good rusk
# 예측 요약문 :  good product
#
#
# 원문 :  used couple week far result maybe ha long enough
# 실제 요약문 : tomato
# 예측 요약문 :  work
#
#
# 원문 :  thi favorite special treat peanut butter home favored especially yr old daughter wa prized item care package sent college finding available amazon thi price gold mine favored flavor although eaten little les often chocolate
# 실제 요약문 : favorite house
# 예측 요약문 :  love thi product
#
#
# 원문 :  good price good quality convenience fully met expectation would recommend breakfast blend wa mild nice start morning
# 실제 요약문 : pleased
# 예측 요약문 :  good coffee
#
#
# 원문 :  wa skeptic first decided try honey crystal fraction sugar carb cal regular honey flavour great substitute last long time little goe long way
# 실제 요약문 : better honey
# 예측 요약문 :  great product
#
#
# 원문 :  fan swis knight fondue year able find home vermont live delightful able order thi treat anytime btw agree suggestion heat fondue putting fondue pot microwave work fine doe melting top half double boiler
# 실제 요약문 : delighted find thi online
# 예측 요약문 :  best
#
#
# 원문 :  bought recently year old boxer mix different kind retriever roll getting honestly say best come acros tightly wrapped pressed end seal unroll thi make durable chewing experience ha really gotta work chew mean chewing time going slower pace thing wish made usa otherwise great product
# 실제 요약문 : best bone buck
# 예측 요약문 :  great chew toy
#
#
# 원문 :  know taste subjective really like thi plain coconut water naked doe weird bean ish flavor experienced brand fine drink plain mixed juice bitter sour even make chocolate smoothie sometime doe add weird flavor chocolate really deliciou would take one star price think coconut water overpriced pregnant thi stuff great keeping hydrated
# 실제 요약문 : light fresh weird aftertaste
# 예측 요약문 :  deliciou
#
#
# 원문 :  product arrived timely manner exactly described taste like true spanish saffron completely cheap mexican type well worth price
# 실제 요약문 : back spain
# 예측 요약문 :  good quality
#
#
# 원문 :  cat used eat wellnes core dry food slowly ate les les tried find food still high protein grain free problem finishe hi food fast
# 실제 요약문 : cat love
# 예측 요약문 :  cat love
#
#
# 원문 :  wa impressed get poptart low price seemed fall apart easily something delivery great snak breakfast item may better getting store
# 실제 요약문 : yummy bit crumbly
# 예측 요약문 :  good
#
#
# 원문 :  purchased thi coffee normal source jamaica blue mountain bean ran week marley coffee wa great quality smell like jamaica blue mountain bean purchased source smelled musky damp deliciou taste wa also disappointing sum wil purchase thi recommend
# 실제 요약문 : disappointing
# 예측 요약문 :  coffee bean
#
#
# 원문 :  thi wa easy install reading review decided use included screw bottom cabinet ha rough texture doubt adhesive would held long use keep rack place screwed love keep countertop clutter free thi far best storage cup
# 실제 요약문 : great storage cup
# 예측 요약문 :  great idea
#
#
# 원문 :  thi superb oatmeal ha marvelou flavor texture oatmeal lover eat every season year mccann standard steel cut product choice well worth extra cost drawback may cooking time prepare conventional pot stove technique according package instruction must boil thicken simmer minute thi avoided pressure cooker use cooking time device minute combine cup water cup oat thi make large serving refrigerate savor several day bon appetit
# 실제 요약문 : excellent product particularly pressure cooker
# 예측 요약문 :  best oatmeal ever
#
#
# 원문 :  entire aisle devoted cracker local grocery store carrie swis flavored cracker chedder america favorite doe mean flavor
# 실제 요약문 : hard get
# 예측 요약문 :  love thi product
#
#
# 원문 :  used find local supermarket search web friend like usually try buy halloween favorite product seem come go
# 실제 요약문 : variation tootsie roll mini
# 예측 요약문 :  love thi tea
#
#
# 원문 :  thi stuff taste awful taste sour kind artificial consistancy glue like tried mix olive oil since hate throwing away food help full jar went trash bin
# 실제 요약문 : really bad
# 예측 요약문 :  horrible
#
#
# 원문 :  wa really worried ordered thi phantom power would make apparently wa worried nothing use thi paired blue pro seriously beefy microphone running cable eighty feet away absolutely great one downside seen thi piece kit occasionally register usb device granted seen happen alway want double check connection
# 실제 요약문 : cold ice
# 예측 요약문 :  nice
#
#
# 원문 :  good tasting jerky high protein calorie ratio good protein powder ratio filling snack
# 실제 요약문 : love
# 예측 요약문 :  good
#
#
# 원문 :  almost boy ha asking orange nugo bar month apparently tried one school kid allegedly love say hi favorite unfortunately could find thi flavor store around mill valley area ha tried chocolate chocolate peanut butter variou dark chocolate flavor ha tried many major brand protein bar tricky ha brace seem fine like said like rice krispie treat healthier lot similar product market
# 실제 요약문 : middle school favorite
# 예측 요약문 :  love bar
#
#
# 원문 :  milk good soap creamy like transaction amazon wa exceptional
# 실제 요약문 : coconut milk
# 예측 요약문 :  good
#
#
# 원문 :  great product great service needed small easter gift package size wa perfect handout children well adult impressed little bag bean inside perfect
# 실제 요약문 : great service
# 예측 요약문 :  great
#
#
# 원문 :  received package raisin reasonable amount time wa totally satisfied purchase
# 실제 요약문 : raisin review
# 예측 요약문 :  raisin bran
#
#
# 원문 :  taste great use whole lot get flavor buy thi product
# 실제 요약문 : yum
# 예측 요약문 :  great product
#
#
# 원문 :  know got bad batch thi coffee ha nasty plastic flavor think nantucket blend good dark magic excellent room mate tried twice also think breakfast blend terrible green mountain make good coffee experience thi one
# 실제 요약문 : favorite green mountain
# 예측 요약문 :  worst coffee ever
#
#
# 원문 :  using thi deodorant quite year alway happy way work also scent found pack amazon wa also available subscribe save section thi cheapest way possibly purchase thi deodorant
# 실제 요약문 : work great smell even better
# 예측 요약문 :  love thi stuff
#
#
# 원문 :  flaxseed good quality eat daily bought whole seed rather ground seed better nutritional value grinding buy read whole seed pas undigested ground seed loose nutritional value time grind week worth time best used oatmeal flavor blend well cold cereal added cup coffee twist seem blend better hot food
# 실제 요약문 : good seed
# 예측 요약문 :  great product
#
#
# 원문 :  crying thi product wanted equal spent money bought equal thing wrong thi product
# 실제 요약문 : good stuff
# 예측 요약문 :  product
#
#
# 원문 :  thi nice set reviewer paid would paid cocoa pouche made paper wa punctured box chocolate next thi resulted lost cocoa big mes clean could send thi recipient sad lost product doe stay box well without plastic
# 실제 요약문 : cocoa bag paper big mes
# 예측 요약문 :  poor quality
#
#
# 원문 :  big rip charge twice normal price go dr website get thing half price
# 실제 요약문 : rip
# 예측 요약문 :  rip
#
#
# 원문 :  buying coffee bean direct coffee year disappointed love coffee consider ourselve brew snob money saving think find better coffee thi wa purchased gift one comment bean roasted day shipping
# 실제 요약문 : great bang buck
# 예측 요약문 :  coffee
#
#
# 원문 :  love trying different salt seasoning say thi may favorite salt ever use everything believe much flavor difference little amount make smell divine already ordering plan give friend gift like mushroom love thi salt highly recommended
# 실제 요약문 : best salt ever
# 예측 요약문 :  love thi salt
#
#
# 원문 :  second bite one teeth broke wa enough turn careful chew
# 실제 요약문 : broke tooth one bar
# 예측 요약문 :  hard chew
#
#
# 원문 :  altho back ordered promised continue use thi product happy recommend anyone work
# 실제 요약문 : magic tea
# 예측 요약문 :  great product
#
#
# 원문 :  dog got mad could get treat ripped rope right pretty strong chewer extraordinary ha lb coonhound fyi ya thought wa little difficult get treat maybe dog smartest anyway search continue perfect dog toy
# 실제 요약문 : strong chewer whipped hour
# 예측 요약문 :  dog love
#
#
# 원문 :  wa kid illinoi could get mallomar nashville never seen substitute pinwheel pinwheel mallomar mallomar ha intense chocolate flavor soft inside nice flaky tender cookie flavor like mallomar want taste pinwheel wishe could grow buy mallomar
# 실제 요약문 : still get thing
# 예측 요약문 :  mallomar
#
#
# 원문 :  golden whose hair tend smell thi product significantly reduce problem adopted golden wa extremely overweight smell great week eating thi dog food wa recommended friend began lose weight smell better year half later ha great shape smell like dog product doe contain corn
# 실제 요약문 : golden retriver love

# %%
encoder_input_test
# Out:
# array([[  75,    1,   32, ...,    0,    0,    0],
#        [  75,  652,   95, ...,    0,    0,    0],
#        [  51,  329,   74, ...,    0,    0,    0],
#        ...,
#        [ 169,   37,  587, ...,    0,    0,    0],
#        [   9, 2204,  934, ...,    0,    0,    0],
#        [  70, 1313,  142, ...,    0,    0,    0]], dtype=int32)
